# %% [markdown]
# #LinearRegression

# %% [markdown]
# *Importing Libraries*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# *Reading CSV*

# %%
data=pd.read_csv("/content/Linear Regression - Sheet1.csv")
data
# Out:
#        X           Y
# 0      1    3.888889
# 1      2    4.555556
# 2      3    5.222222
# 3      4    5.888889
# 4      5    6.555556
# ..   ...         ...
# 295  296  200.555556
# 296  297  201.222222
# 297  298  201.888889
# 298  299    1.888889
# 299  300    1.888889
#
# [300 rows x 2 columns]

# %%
data.shape
# Out:
# (300, 2)

# %% [markdown]
# *Statistical Deatils*

# %%
data.describe()
# Out:
#                 X           Y
# count  300.000000  300.000000
# mean   150.500000  102.215556
# std     86.746758   57.842711
# min      1.000000    1.888889
# 25%     75.750000   52.388889
# 50%    150.500000  102.222222
# 75%    225.250000  152.055556
# max    300.000000  201.888889

# %%
x=pd.DataFrame(data["X"])
y=pd.DataFrame(data["Y"])

# %% [markdown]
# *Spliting DataSets*

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

# %%
print(x.shape , X_train, X_test)
print(y.shape,y_train,y_test)
# Out:
# (300, 1)        X
# 12    13
# 3      4
# 183  184
# 37    38
# 165  166
# ..   ...
# 46    47
# 118  119
# 92    93
# 299  300
# 39    40
#
# [240 rows x 1 columns]        X
# 85    86
# 231  232
# 289  290
# 195  196
# 170  171
# 44    45
# 262  263
# 182  183
# 250  251
# 185  186
# 246  247
# 125  126
# 59    60
# 178  179
# 15    16
# 159  160
# 132  133
# 148  149
# 158  159
# 190  191
# 215  216
# 253  254
# 232  233
# 98    99
# 1      2
# 136  137
# 84    85
# 25    26
# 252  253
# 103  104
# 184  185
# 241  242
# 131  132
# 194  195
# 214  215
# 120  121
# 268  269
# 235  236
# 201  202
# 251  252
# 56    57
# 290  291
# 6      7
# 62    63
# 155  156
# 298  299
# 66    67
# 197  198
# 238  239
# 293  294
# 275  276
# 260  261
# 114  115
# 83    84
# 222  223
# 100  101
# 64    65
# 180  181
# 78    79
# 113  114
# (300, 1)               Y
# 12    11.888889
# 3      5.888889
# 183  125.888889
# 37    28.555556
# 165  113.888889
# ..          ...
# 46    34.555556
# 118   82.555556
# 92    65.222222
# 299    1.888889
# 39    29.888889
#
# [240 rows x 1 columns]               Y
# 85    60.555556
# 231  157.888889
# 289  196.555556
# 195  133.888889
# 170  117.222222
# 44    33.222222
# 262  178.555556
# 182  125.222222
# 250  170.555556
# 185  127.222222
# 246  167.888889
# 125   87.222222
# 59    43.222222
# 178  122.555556
# 15    13.888889
# 159  109.888889
# 132   91.888889
# 148  102.555556
# 158  109.222222
# 190  130.555556
# 215  147.222222
# 253  172.555556
# 232  158.555556
# 98    69.222222
# 1      4.555556
# 136   94.555556
# 84    59.888889
# 25    20.555556
# 252  171.888889
# 103   72.555556
# 184  126.555556
# 241  164.555556
# 131   91.222222
# 194  133.222222
# 214  146.555556
# 120   83.888889
# 268  182.555556
# 235  160.555556
# 201  137.888889
# 251  171.222222
# 56    41.222222
# 290  197.222222
# 6      7.888889
# 62    45.222222
# 155  107.222222
# 298    1.888889
# 66    47.888889
# 197  135.222222
# 238  162.555556
# 293  199.222222
# 275  187.222222
# 260  177.222222
# 114   79.888889
# 83    59.222222
# 222  151.888889
# 100   70.555556
# 64    46.555556
# 180  123.888889
# 78    55.888889
# 113   79.222222

# %% [markdown]
# *Importing LinearRegression Model*

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()

# %%
LR.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict = LR.predict(X_test)
y_predict
# Out:
# array([[ 60.73697733],
#        [155.61466911],
#        [193.30580694],
#        [132.22016976],
#        [115.97398967],
#        [ 34.09324197],
#        [175.75993243],
#        [123.77215611],
#        [167.96176598],
#        [125.72169773],
#        [165.36237717],
#        [ 86.73086549],
#        [ 43.84095003],
#        [121.1727673 ],
#        [ 15.24767305],
#        [108.82567042],
#        [ 91.27979592],
#        [101.67735118],
#        [108.17582322],
#        [128.97093374],
#        [145.21711384],
#        [169.91130759],
#        [156.26451631],
#        [ 69.18499098],
#        [  6.1498122 ],
#        [ 93.87918473],
#        [ 60.08713012],
#        [ 21.74614509],
#        [169.26146039],
#        [ 72.434227  ],
#        [125.07185052],
#        [162.11314115],
#        [ 90.62994871],
#        [131.57032256],
#        [144.56726664],
#        [ 83.48162947],
#        [179.65901565],
#        [158.21405792],
#        [136.11925299],
#        [168.61161319],
#        [ 41.89140841],
#        [193.95565414],
#        [  9.39904822],
#        [ 45.79049164],
#        [106.22628161],
#        [199.15443177],
#        [ 48.38988045],
#        [133.51986417],
#        [160.16359954],
#        [195.90519575],
#        [184.20794608],
#        [174.46023802],
#        [ 79.58254624],
#        [ 59.43728292],
#        [149.76604427],
#        [ 70.48468539],
#        [ 47.09018605],
#        [122.47246171],
#        [ 56.1880469 ],
#        [ 78.93269904]])

# %%
print(LR.intercept_)
print(LR.coef_)
# Out:
# [4.85011779]
# [[0.6498472]]

# %% [markdown]
# *Checking the model how it's perfomance*

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, y_predict)
print('R2 Score = ', score)
# Out:
# R2 Score =  0.7832042277036348
